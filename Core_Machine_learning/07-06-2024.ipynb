# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# use in windows to access directories
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 38C8-8BCD
#
#  Directory of C:\Users\Dell\class_June
#
# 06/12/2024  08:10 AM    <DIR>          .
# 06/03/2024  12:07 PM    <DIR>          ..
# 06/11/2024  07:10 PM    <DIR>          .ipynb_checkpoints
# 06/07/2024  09:56 AM             5,603 05-06-2024.ipynb
# 06/12/2024  08:10 AM           402,441 07-06-2024.ipynb
# 06/04/2024  10:04 PM             5,333 22051590_Day_10_Task.ipynb
# 06/03/2024  01:02 PM            13,302 3-06-2024.ipynb
# 06/11/2024  07:21 PM    <DIR>          iris
# 06/08/2024  04:39 PM            11,684 Numpy_exercise_solution.ipynb
# 06/08/2024  05:20 PM            27,317 Numpy_Test_Solution.ipynb
# 06/03/2024  04:07 PM            11,028 Stats_Task_01.ipynb
# 06/04/2024  11:21 AM             8,445 Stats_Task_02.ipynb
# 06/04/2024  01:22 PM            13,154 Task_Day_09.ipynb
#                9 File(s)        498,307 bytes
#                4 Dir(s)  269,708,681,216 bytes free

# %%
#head
def head(fpath):
    with open(fpath) as file:
        i=0
        for line in file :
            print(line)
            i += 1
            if i == 5:
                break

# %%
df = pd.read_csv('iris/bezdekIris.data')
print(df.head())
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
head('iris/bezdekIris.data')
# Out:
# 5.1,3.5,1.4,0.2,Iris-setosa
#
# 4.9,3.0,1.4,0.2,Iris-setosa
#
# 4.7,3.2,1.3,0.2,Iris-setosa
#
# 4.6,3.1,1.5,0.2,Iris-setosa
#
# 5.0,3.6,1.4,0.2,Iris-setosa

# %%
head('iris/iris.data')
# Out:
# 5.1,3.5,1.4,0.2,Iris-setosa
#
# 4.9,3.0,1.4,0.2,Iris-setosa
#
# 4.7,3.2,1.3,0.2,Iris-setosa
#
# 4.6,3.1,1.5,0.2,Iris-setosa
#
# 5.0,3.6,1.4,0.2,Iris-setosa

# %%
head('iris/iris.names')
# Out:
# 1. Title: Iris Plants Database
#
# 	Updated Sept 21 by C.Blake - Added discrepency information
#
#
#
# 2. Sources:
#
#      (a) Creator: R.A. Fisher

# %%
columns = ['sepal length','sepal width','petal length','petal width','class']

# %% [markdown]
# ![image.png](attachment:072bbe68-d2ae-4e09-b404-edaed705c2b7.png)

# %%
df = pd.read_csv('iris/iris.data', header=None , names=columns)
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.plot("sepal length","sepal width",kind="scatter")
plt.show()

# %% [markdown]
# #### Drop

# %%
temp = pd.DataFrame({
    "A": np.random.randint(1,100,10),
    "B": np.random.randint(1,100,10),
    "C": np.random.randint(1,100,10)
},
      index= pd.date_range("06/07/2024",periods=10))

# %%
temp
# Out:
#              A   B   C
# 2024-06-07  17  89  88
# 2024-06-08  98  81  88
# 2024-06-09  70  75  53
# 2024-06-10  63  94  50
# 2024-06-11   7  35  34
# 2024-06-12  34  18  11
# 2024-06-13  34  71  79
# 2024-06-14  77  31  95
# 2024-06-15  45  11  25
# 2024-06-16  42  57  62

# %%
temp.iloc[-1,:] = np.nan

# %%
temp.iloc[3,2] = np.nan

# %%
temp.iloc[5,1] = np.nan

# %%
temp
# Out:
#                A     B     C
# 2024-06-07  17.0  89.0  88.0
# 2024-06-08  98.0  81.0  88.0
# 2024-06-09  70.0  75.0  53.0
# 2024-06-10  63.0  94.0   NaN
# 2024-06-11   7.0  35.0  34.0
# 2024-06-12  34.0   NaN  11.0
# 2024-06-13  34.0  71.0  79.0
# 2024-06-14  77.0  31.0  95.0
# 2024-06-15  45.0  11.0  25.0
# 2024-06-16   NaN   NaN   NaN

# %% [markdown]
# #### missing values

# %%
# to check missing values
temp.isna()
# Out:
#                 A      B      C
# 2024-06-07  False  False  False
# 2024-06-08  False  False  False
# 2024-06-09  False  False  False
# 2024-06-10  False  False   True
# 2024-06-11  False  False  False
# 2024-06-12  False   True  False
# 2024-06-13  False  False  False
# 2024-06-14  False  False  False
# 2024-06-15  False  False  False
# 2024-06-16   True   True   True

# %%
# to get total number of missing values in a column
temp.isna().sum()
# Out:
# A    1
# B    2
# C    2
# dtype: int64

# %%
# if you want to check in rows
temp.isna().sum(axis=1)
# Out:
# 2024-06-07    0
# 2024-06-08    0
# 2024-06-09    0
# 2024-06-10    1
# 2024-06-11    0
# 2024-06-12    1
# 2024-06-13    0
# 2024-06-14    0
# 2024-06-15    0
# 2024-06-16    3
# Freq: D, dtype: int64

# %%
d = temp.copy()

# %%
d
# Out:
#                A     B     C
# 2024-06-07  17.0  89.0  88.0
# 2024-06-08  98.0  81.0  88.0
# 2024-06-09  70.0  75.0  53.0
# 2024-06-10  63.0  94.0   NaN
# 2024-06-11   7.0  35.0  34.0
# 2024-06-12  34.0   NaN  11.0
# 2024-06-13  34.0  71.0  79.0
# 2024-06-14  77.0  31.0  95.0
# 2024-06-15  45.0  11.0  25.0
# 2024-06-16   NaN   NaN   NaN

# %%
d.fillna(0)
# Out:
#                A     B     C
# 2024-06-07  17.0  89.0  88.0
# 2024-06-08  98.0  81.0  88.0
# 2024-06-09  70.0  75.0  53.0
# 2024-06-10  63.0  94.0   0.0
# 2024-06-11   7.0  35.0  34.0
# 2024-06-12  34.0   0.0  11.0
# 2024-06-13  34.0  71.0  79.0
# 2024-06-14  77.0  31.0  95.0
# 2024-06-15  45.0  11.0  25.0
# 2024-06-16   0.0   0.0   0.0

# %%
# if you want to know what percentage of value is missing in your dataframe then
d.isna().sum()/d.shape[0]
# Out:
# A    0.1
# B    0.2
# C    0.2
# dtype: float64

# %%
d.dropna() # axis = 0, inplace = True
# Out:
#                A     B     C
# 2024-06-07  17.0  89.0  88.0
# 2024-06-08  98.0  81.0  88.0
# 2024-06-09  70.0  75.0  53.0
# 2024-06-11   7.0  35.0  34.0
# 2024-06-13  34.0  71.0  79.0
# 2024-06-14  77.0  31.0  95.0
# 2024-06-15  45.0  11.0  25.0

# %%
d.dropna(how="all")
# Out:
#                A     B     C
# 2024-06-07  17.0  89.0  88.0
# 2024-06-08  98.0  81.0  88.0
# 2024-06-09  70.0  75.0  53.0
# 2024-06-10  63.0  94.0   NaN
# 2024-06-11   7.0  35.0  34.0
# 2024-06-12  34.0   NaN  11.0
# 2024-06-13  34.0  71.0  79.0
# 2024-06-14  77.0  31.0  95.0
# 2024-06-15  45.0  11.0  25.0

# %%
d.loc[:,"D"]=np.nan

# %%
d.dropna(how="all",inplace=True)

# %%
d
# Out:
#                A     B     C   D
# 2024-06-07  17.0  89.0  88.0 NaN
# 2024-06-08  98.0  81.0  88.0 NaN
# 2024-06-09  70.0  75.0  53.0 NaN
# 2024-06-10  63.0  94.0   NaN NaN
# 2024-06-11   7.0  35.0  34.0 NaN
# 2024-06-12  34.0   NaN  11.0 NaN
# 2024-06-13  34.0  71.0  79.0 NaN
# 2024-06-14  77.0  31.0  95.0 NaN
# 2024-06-15  45.0  11.0  25.0 NaN

# %%
d.dropna(axis=1)
# Out:
#                A
# 2024-06-07  17.0
# 2024-06-08  98.0
# 2024-06-09  70.0
# 2024-06-10  63.0
# 2024-06-11   7.0
# 2024-06-12  34.0
# 2024-06-13  34.0
# 2024-06-14  77.0
# 2024-06-15  45.0

# %%
d.dropna(axis=1,how="all",inplace=True)

# %%
d
# Out:
#                A     B     C
# 2024-06-07  17.0  89.0  88.0
# 2024-06-08  98.0  81.0  88.0
# 2024-06-09  70.0  75.0  53.0
# 2024-06-10  63.0  94.0   NaN
# 2024-06-11   7.0  35.0  34.0
# 2024-06-12  34.0   NaN  11.0
# 2024-06-13  34.0  71.0  79.0
# 2024-06-14  77.0  31.0  95.0
# 2024-06-15  45.0  11.0  25.0

# %%
df.hist(bins=30)
# Out:
# array([[<Axes: title={'center': 'sepal length'}>,
#         <Axes: title={'center': 'sepal width'}>],
#        [<Axes: title={'center': 'petal length'}>,
#         <Axes: title={'center': 'petal width'}>]], dtype=object)

# %%
cm = d.median().to_dict()
cm
# Out:
# {'A': 45.0, 'B': 73.0, 'C': 66.0}

# %%
d.fillna(cm) #most common way to drop na values
# Out:
#                A     B     C
# 2024-06-07  17.0  89.0  88.0
# 2024-06-08  98.0  81.0  88.0
# 2024-06-09  70.0  75.0  53.0
# 2024-06-10  63.0  94.0  66.0
# 2024-06-11   7.0  35.0  34.0
# 2024-06-12  34.0  73.0  11.0
# 2024-06-13  34.0  71.0  79.0
# 2024-06-14  77.0  31.0  95.0
# 2024-06-15  45.0  11.0  25.0

# %%
d
# Out:
#                A     B     C
# 2024-06-07  17.0  89.0  88.0
# 2024-06-08  98.0  81.0  88.0
# 2024-06-09  70.0  75.0  53.0
# 2024-06-10  63.0  94.0   NaN
# 2024-06-11   7.0  35.0  34.0
# 2024-06-12  34.0   NaN  11.0
# 2024-06-13  34.0  71.0  79.0
# 2024-06-14  77.0  31.0  95.0
# 2024-06-15  45.0  11.0  25.0

# %%
d.fillna(method='ffill')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9108\2958235498.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   d.fillna(method='ffill')
#                A     B     C
# 2024-06-07  17.0  89.0  88.0
# 2024-06-08  98.0  81.0  88.0
# 2024-06-09  70.0  75.0  53.0
# 2024-06-10  63.0  94.0  53.0
# 2024-06-11   7.0  35.0  34.0
# 2024-06-12  34.0  35.0  11.0
# 2024-06-13  34.0  71.0  79.0
# 2024-06-14  77.0  31.0  95.0
# 2024-06-15  45.0  11.0  25.0

# %%
d.fillna(method='bfill')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9108\3117391051.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   d.fillna(method='bfill')
#                A     B     C
# 2024-06-07  17.0  89.0  88.0
# 2024-06-08  98.0  81.0  88.0
# 2024-06-09  70.0  75.0  53.0
# 2024-06-10  63.0  94.0  34.0
# 2024-06-11   7.0  35.0  34.0
# 2024-06-12  34.0  71.0  11.0
# 2024-06-13  34.0  71.0  79.0
# 2024-06-14  77.0  31.0  95.0
# 2024-06-15  45.0  11.0  25.0

# %%
d.bfill()
# Out:
#                A     B     C
# 2024-06-07  17.0  89.0  88.0
# 2024-06-08  98.0  81.0  88.0
# 2024-06-09  70.0  75.0  53.0
# 2024-06-10  63.0  94.0  34.0
# 2024-06-11   7.0  35.0  34.0
# 2024-06-12  34.0  71.0  11.0
# 2024-06-13  34.0  71.0  79.0
# 2024-06-14  77.0  31.0  95.0
# 2024-06-15  45.0  11.0  25.0

# %%
temp["D"]=np.nan

# %%
temp
# Out:
#                A     B     C   D
# 2024-06-07  17.0  89.0  88.0 NaN
# 2024-06-08  98.0  81.0  88.0 NaN
# 2024-06-09  70.0  75.0  53.0 NaN
# 2024-06-10  63.0  94.0   NaN NaN
# 2024-06-11   7.0  35.0  34.0 NaN
# 2024-06-12  34.0   NaN  11.0 NaN
# 2024-06-13  34.0  71.0  79.0 NaN
# 2024-06-14  77.0  31.0  95.0 NaN
# 2024-06-15  45.0  11.0  25.0 NaN
# 2024-06-16   NaN   NaN   NaN NaN

# %%
temp.drop('2024-06-16')
# Out:
#                A     B     C   D
# 2024-06-07  17.0  89.0  88.0 NaN
# 2024-06-08  98.0  81.0  88.0 NaN
# 2024-06-09  70.0  75.0  53.0 NaN
# 2024-06-10  63.0  94.0   NaN NaN
# 2024-06-11   7.0  35.0  34.0 NaN
# 2024-06-12  34.0   NaN  11.0 NaN
# 2024-06-13  34.0  71.0  79.0 NaN
# 2024-06-14  77.0  31.0  95.0 NaN
# 2024-06-15  45.0  11.0  25.0 NaN

# %%
temp.drop(['2024-06-16','2024-06-12'])
# Out:
#                A     B     C   D
# 2024-06-07  17.0  89.0  88.0 NaN
# 2024-06-08  98.0  81.0  88.0 NaN
# 2024-06-09  70.0  75.0  53.0 NaN
# 2024-06-10  63.0  94.0   NaN NaN
# 2024-06-11   7.0  35.0  34.0 NaN
# 2024-06-13  34.0  71.0  79.0 NaN
# 2024-06-14  77.0  31.0  95.0 NaN
# 2024-06-15  45.0  11.0  25.0 NaN

# %%
temp.drop('D',axis=1,inplace=True)

# %%
temp
# Out:
#                A     B     C
# 2024-06-07  17.0  89.0  88.0
# 2024-06-08  98.0  81.0  88.0
# 2024-06-09  70.0  75.0  53.0
# 2024-06-10  63.0  94.0   NaN
# 2024-06-11   7.0  35.0  34.0
# 2024-06-12  34.0   NaN  11.0
# 2024-06-13  34.0  71.0  79.0
# 2024-06-14  77.0  31.0  95.0
# 2024-06-15  45.0  11.0  25.0
# 2024-06-16   NaN   NaN   NaN

# %%
df
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df["class"].nunique()
# Out:
# 3

# %%
df['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['class'].value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df['class'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='class'>

# %%
iris = df.copy()

# %%
iris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Transfomation
#
# converting values of data into other values just like converting an int to float
#
#
# data with null values -> transform -> data with not null values
#
#
# 1000 -> transform -> 900

# %%
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris['class'].str.split("-",expand=True)
# Out:
#         0          1
# 0    Iris     setosa
# 1    Iris     setosa
# 2    Iris     setosa
# 3    Iris     setosa
# 4    Iris     setosa
# ..    ...        ...
# 145  Iris  virginica
# 146  Iris  virginica
# 147  Iris  virginica
# 148  Iris  virginica
# 149  Iris  virginica
#
# [150 rows x 2 columns]

# %%
iris = df.copy()

# %%
iris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.loc[:,1] = iris['class'].str.split('-',expand=True).loc[:,1]

# %%
iris
# Out:
#      sepal length  sepal width  petal length  petal width           class  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#              1
# 0       setosa
# 1       setosa
# 2       setosa
# ...

# %%
iris.drop(1,axis=1,inplace=True)

# %%
iris.loc[:,'class'] = iris['class'].str.split('-',expand=True).loc[:,1]

# %%
iris
# Out:
#      sepal length  sepal width  petal length  petal width      class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['class'].apply(lambda value: value.split('-')[1])
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: class, Length: 150, dtype: object

# %%
df['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
m = {'Iris-setosa': 'setosa', 'Iris-versicolor': 'versicolor', 'Iris-virginica': 'virginica'}

# %%
df['class'].map(m) #works well in categorical data type
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: class, Length: 150, dtype: object
