# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = sns.load_dataset("flights")
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
ans = df.groupby("year")["passengers"].mean().reset_index()
ans
# Out:
#     year  passengers
# 0   1949  126.666667
# 1   1950  139.666667
# 2   1951  170.166667
# 3   1952  197.000000
# 4   1953  225.000000
# 5   1954  238.916667
# 6   1955  284.000000
# 7   1956  328.250000
# 8   1957  368.416667
# 9   1958  381.000000
# 10  1959  428.333333
# 11  1960  476.166667

# %% [raw]
# dpi = 100 -> density per pixels
#
# 6*100 , 4*100
#
# 600x400

# %%
fig = plt.figure(figsize=(6,4),facecolor="gold",dpi=100)
axes = fig.add_axes([0,0,1,1])
axes.plot("year","passengers",ls='--',marker='o',mfc='red',ms=10,mec='black',data=ans,label="data")
axes.set_title("passengers over the years")
axes.set_xlabel("Year")
axes.set_ylabel("no of passengers")
axes.grid()
axes.legend()
plt.show()

# %% [markdown]
# ### Line plot
#
# ->Time series data or any continuous variable can be shown as line plot
#
# -> Data should be numerical

# %%
x = np.linspace(-30,30,100)

plt.plot(x,marker = 'o',ms=10,mfc='r',ls='--',mec='black',data=x,alpha=0.2)

# %%
import matplotlib as mpl
mpl.defaultParams
# Out:
# {'backend': [<object at 0x1be6908cdd0>,
#   <function matplotlib.rcsetup.validate_backend(s)>],
#  'backend_fallback': [True, <function matplotlib.rcsetup.validate_bool(b)>],
#  'figure.hooks': [[],
#   <function matplotlib.rcsetup._listify_validator.<locals>.validate_strlist(s)>],
#  'toolbar': ['toolbar2', <function matplotlib.rcsetup._validate_toolbar(s)>],
#  'interactive': [False, <function matplotlib.rcsetup.validate_bool(b)>],
#  'timezone': ['UTC',
#   <function matplotlib.rcsetup._make_type_validator.<locals>.validate_str(s)>],
#  'webagg.port': [8988,
#   <function matplotlib.rcsetup._make_type_validator.<locals>.validate_int(s)>],
#  'webagg.address': ['127.0.0.1',
#   <function matplotlib.rcsetup._make_type_validator.<locals>.validate_str(s)>],
#  'webagg.open_in_browser': [True,
#   <function matplotlib.rcsetup.validate_bool(b)>],
#  'webagg.port_retries': [50,
#   <function matplotlib.rcsetup._make_type_validator.<locals>.validate_int(s)>],
#  'lines.linewidth': [1.5,
# ...

# %%
mpl.defaultParams["figure.figsize"]
# Out:
# [[6.4, 4.8],
#  <function matplotlib.rcsetup._listify_validator.<locals>.validate_floatlist(s)>]

# %%
mpl.defaultParams["figure.dpi"]
# Out:
# [100.0,
#  <function matplotlib.rcsetup._make_type_validator.<locals>.validate_float(s)>]

# %%
x = np.linspace(-1,1,20)
plt.figure(figsize=(8,4))
plt.plot(x,x,"b--o",x,x**2,'r:+',x,x**3,'m:d',alpha=0.5)

# %%
x = np.linspace(-30,30,20)
plt.figure(figsize=(8,4))
plt.plot(x,x,"b--o",x,x**2,'r:+',x,x**3,'m:d',alpha=0.5)
plt.yscale('log')

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.year.unique()
# Out:
# array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960], dtype=int64)

# %%
new_df = df.pivot_table(columns='year',index='month',values='passengers')

# %%
new_df
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
plt.plot(new_df[1959],ls='--',marker='o',mfc='r',ms=10,color='k',mec='y',label='1959')
plt.plot(new_df[1960],ls=':',marker='s',mfc='b',ms=10,color='g',mec='k',label='1960')
plt.legend(loc='upper left',edgecolor='k')
plt.title("Trend of Passengers over the year",color='red',
          fontdict={"fontsize":10,"family":"cursive","weight":0})
axes = plt.gca() # get current axes
axes.spines["right"].set_visible(False)
axes.spines["top"].set_visible(False)
axes.spines["left"].set_linestyle(":")
# axes.set_xticklabels(xticks,labels)
#first set ticks then go for labels
axes.set_xticks(new_df.index)
axes.set_xticklabels(new_df.index,color='r')

yticks = np.arange(300,700,25)
axes.set_yticks(yticks)
axes.set_yticklabels([f"{chr(65+i)}-{yticks[i]}" for i in range(16)],color='b')
#set_yticks(ticks,tick_labels)
#set_yticklabels(tick_labels) #make sure to set the ticks

axes.grid(ls=':',color='m',alpha=0.8)
axes.text(1,575,"Navneet Tiwari",color='r',fontsize=15,alpha=0.7)

from matplotlib.patches import Rectangle
rct = Rectangle((0.5,575),5,30,edgecolor='k',alpha=0.2,facecolor='w')
axes.add_patch(rct)
plt.show()

# %%
axes.get_xticklabels()
# Out:
# [Text(0, 0, 'Jan'),
#  Text(1, 0, 'Feb'),
#  Text(2, 0, 'Mar'),
#  Text(3, 0, 'Apr'),
#  Text(4, 0, 'May'),
#  Text(5, 0, 'Jun'),
#  Text(6, 0, 'Jul'),
#  Text(7, 0, 'Aug'),
#  Text(8, 0, 'Sep'),
#  Text(9, 0, 'Oct'),
#  Text(10, 0, 'Nov'),
#  Text(11, 0, 'Dec')]

# %%
labels = axes.get_xticklabels()
axes.set_xticklabels(labels)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_20420\1353549722.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(labels)
# [Text(0, 0, 'Jan'),
#  Text(1, 0, 'Feb'),
#  Text(2, 0, 'Mar'),
#  Text(3, 0, 'Apr'),
#  Text(4, 0, 'May'),
#  Text(5, 0, 'Jun'),
#  Text(6, 0, 'Jul'),
#  Text(7, 0, 'Aug'),
#  Text(8, 0, 'Sep'),
#  Text(9, 0, 'Oct'),
#  Text(10, 0, 'Nov'),
#  Text(11, 0, 'Dec')]
