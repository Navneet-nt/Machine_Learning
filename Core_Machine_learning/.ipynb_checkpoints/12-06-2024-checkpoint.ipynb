# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### scatter plot
#
# -> to find out relationship between two variables

# %% [raw]
# Bi-variate
# -> comparison between two variables
#
# Multi-variate
# -> comparison between multiple variables

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [raw]
# if we use line plot for data that is not sequential then there is no point in doing so therefore we use scatter plot when data is non-sequential

# %%
#line plot
plt.plot("total_bill","tip",data=tips,alpha=0.8)
plt.show()

# %%
# scatter plot
plt.plot("total_bill","tip",'o',data=tips,alpha=0.5)
plt.show()

# %%
plt.plot(tips.total_bill,tips.tip,"H",alpha=0.5,ms=20)
plt.show()

# %%
plt.scatter("total_bill","tip",data=tips,marker="h",alpha=0.6)
plt.show()

# %%
tips["sex"].unique()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Male', 'Female']

# %%
c = tips["sex"].map({"Female":'pink','Male':'yellow'}).to_numpy()
c
# Out:
# array(['pink', 'yellow', 'yellow', 'yellow', 'pink', 'yellow', 'yellow',
#        'yellow', 'yellow', 'yellow', 'yellow', 'pink', 'yellow', 'yellow',
#        'pink', 'yellow', 'pink', 'yellow', 'pink', 'yellow', 'yellow',
#        'pink', 'pink', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow',
#        'yellow', 'pink', 'yellow', 'yellow', 'pink', 'pink', 'yellow',
#        'yellow', 'yellow', 'pink', 'yellow', 'yellow', 'yellow', 'yellow',
#        'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow',
#        'yellow', 'yellow', 'yellow', 'pink', 'pink', 'yellow', 'yellow',
#        'yellow', 'yellow', 'pink', 'yellow', 'yellow', 'yellow', 'yellow',
#        'yellow', 'yellow', 'yellow', 'yellow', 'pink', 'pink', 'yellow',
#        'yellow', 'yellow', 'pink', 'pink', 'pink', 'pink', 'yellow',
#        'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'yellow', 'pink',
#        'yellow', 'yellow', 'pink', 'yellow', 'yellow', 'yellow', 'yellow',
# ...

# %%
tips["smoker"].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
w = tips["smoker"].map({"Yes":"red","No":"green"}).to_numpy()
w
# Out:
# array(['green', 'green', 'green', 'green', 'green', 'green', 'green',
#        'green', 'green', 'green', 'green', 'green', 'green', 'green',
#        'green', 'green', 'green', 'green', 'green', 'green', 'green',
#        'green', 'green', 'green', 'green', 'green', 'green', 'green',
#        'green', 'green', 'green', 'green', 'green', 'green', 'green',
#        'green', 'green', 'green', 'green', 'green', 'green', 'green',
#        'green', 'green', 'green', 'green', 'green', 'green', 'green',
#        'green', 'green', 'green', 'green', 'green', 'green', 'green',
#        'red', 'green', 'red', 'green', 'red', 'red', 'red', 'red',
#        'green', 'green', 'green', 'red', 'green', 'red', 'green', 'green',
#        'red', 'red', 'green', 'green', 'red', 'green', 'green', 'green',
#        'red', 'green', 'green', 'red', 'green', 'green', 'green', 'green',
#        'green', 'green', 'red', 'green', 'red', 'red', 'green', 'red',
# ...

# %%
f = np.append(c,w)
g = np.random.choice(f,size=244,replace=False)
g
# Out:
# array(['red', 'yellow', 'green', 'green', 'pink', 'yellow', 'pink',
#        'yellow', 'yellow', 'pink', 'yellow', 'yellow', 'red', 'yellow',
#        'yellow', 'red', 'green', 'pink', 'green', 'yellow', 'yellow',
#        'pink', 'yellow', 'yellow', 'red', 'green', 'red', 'green',
#        'green', 'green', 'yellow', 'red', 'green', 'green', 'red',
#        'yellow', 'red', 'green', 'pink', 'yellow', 'yellow', 'yellow',
#        'pink', 'green', 'pink', 'yellow', 'yellow', 'yellow', 'yellow',
#        'yellow', 'pink', 'yellow', 'yellow', 'yellow', 'green', 'red',
#        'pink', 'yellow', 'green', 'pink', 'pink', 'pink', 'green',
#        'green', 'pink', 'yellow', 'red', 'green', 'yellow', 'red',
#        'yellow', 'yellow', 'green', 'yellow', 'red', 'green', 'yellow',
#        'red', 'green', 'pink', 'red', 'yellow', 'yellow', 'pink', 'green',
#        'red', 'yellow', 'yellow', 'green', 'green', 'green', 'green',
# ...

# %%
plt.scatter("total_bill","tip",data=tips,marker="h",c=g,s=100,alpha=0.5)
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.title("Relation between tips paid by gender")
plt.grid()
#to show labels using legend()
plt.plot([],[],'h',color='pink',label='Female')
plt.plot([],[],'h',color='yellow',label='Male')
plt.plot([],[],'h',color='red',label='smokers')
plt.plot([],[],'h',color='green',label='non-smokers')
plt.legend()
plt.show()

# %%
sns.set_style("whitegrid")

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="sex",size="smoker",style="size",palette="coolwarm")
plt.show()

# %%
colors = ['red','green','blue','cyan','magenta','pink','purple','gold','silver']

# %%
freq,bins,objs = plt.hist("total_bill",data=tips,bins=20) #static plot
for obj in objs:
    obj.set_facecolor(np.random.choice(colors))

# %%
#fig,(ax1,ax2) = plt.subplots()

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(8,4),sharey=True)

ax1.hist(tips[tips['sex']=='Male']['total_bill'],bins=20,color='red',ec='k')
ax2.hist(tips[tips['sex']=='Female']['total_bill'],bins=20,color='yellow',ec='k')
plt.show()

# %%
from warnings import filterwarnings
filterwarnings(action='ignore')

# %%
sns.displot(data=tips,x='total_bill',hue='sex',rug=True,kind='kde')
plt.show()

# %% [markdown]
# #### Box Plot

# %%
objs = plt.boxplot("total_bill",data=tips,showmeans=True,patch_artist=True)

for obj in objs["caps"]:
    obj.set_linewidth(5)
    obj.set_color("green")
    
for obj in objs['whiskers']:
    obj.set_color("red")
    obj.set_linestyle('-')
    obj.set_linewidth(2)

for obj in objs["fliers"]:
    obj.set_marker("D")
    obj.set_markersize(8)
    obj.set_markerfacecolor("pink")

# %%
sns.boxplot(data=tips,x='sex',y='total_bill',hue='smoker')
plt.show()

# %%
sns.boxenplot(data=tips,x='sex',y='total_bill',hue='smoker')
plt.show()

# %%
#category plot -> we can create any kind of plot
# by default it creates 'strip' plot
sns.catplot(data=tips,x='sex',y='total_bill',kind='violin')

# %%
sns.jointplot(data=tips,x='total_bill',y='tip')
#scatter with histogram
plt.show()

# %%
sns.pairplot(tips)
#tips -> size,total_bill,tip
#tip tip -> histogram,
plt.show()

# %%
d = tips.groupby("day")["total_bill"].mean().reset_index()
d
# Out:
#     day  total_bill
# 0  Thur   17.682742
# 1   Fri   17.151579
# 2   Sat   20.441379
# 3   Sun   21.410000

# %%
plt.bar('day','total_bill',data=d,color=['r','g','b','c'])
plt.show()

# %%
plt.pie(d['total_bill'],labels=d['day'],labeldistance=0.5,autopct='%.2f%%',pctdistance=1.2,
       explode=[0,0,0,0.1],colors=['grey','grey','grey','red'],shadow=True,radius=1)
plt.show()

# %%
from matplotlib.patches import Circle

# %%
a = Circle((0,0),0.2,facecolor='white')

# %%
# donut plot
plt.pie(d['total_bill'],labels=d['day'],labeldistance=0.5,autopct='%.2f%%',pctdistance=1.2,
       explode=[0,0,0,0.1],colors=['grey','grey','grey','red'],shadow=True,radius=1)
plt.gca().add_patch(a)
plt.show()

# %% [raw]
# matplot -> matplotlib
# heatmap,cluster map -> seaborn

# %%
flights = sns.load_dataset("flights").pivot_table(columns="month",index="year")

# %%
flights.head()
# Out:
#       passengers                                                          \
# month        Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep
# year
# 1949       112.0  118.0  132.0  129.0  121.0  135.0  148.0  148.0  136.0
# 1950       115.0  126.0  141.0  135.0  125.0  149.0  170.0  170.0  158.0
# 1951       145.0  150.0  178.0  163.0  172.0  178.0  199.0  199.0  184.0
# 1952       171.0  180.0  193.0  181.0  183.0  218.0  230.0  242.0  209.0
# 1953       196.0  196.0  236.0  235.0  229.0  243.0  264.0  272.0  237.0
#
#
# month    Oct    Nov    Dec
# year
# 1949   119.0  104.0  118.0
# 1950   133.0  114.0  140.0
# 1951   162.0  146.0  166.0
# 1952   191.0  172.0  194.0
# 1953   211.0  180.0  201.0

# %%
# flights = flights.droplevel(level=0,axis=1)
flights.head()
# Out:
# month    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# year
# 1949   112.0  118.0  132.0  129.0  121.0  135.0  148.0  148.0  136.0  119.0
# 1950   115.0  126.0  141.0  135.0  125.0  149.0  170.0  170.0  158.0  133.0
# 1951   145.0  150.0  178.0  163.0  172.0  178.0  199.0  199.0  184.0  162.0
# 1952   171.0  180.0  193.0  181.0  183.0  218.0  230.0  242.0  209.0  191.0
# 1953   196.0  196.0  236.0  235.0  229.0  243.0  264.0  272.0  237.0  211.0
#
# month    Nov    Dec
# year
# 1949   104.0  118.0
# 1950   114.0  140.0
# 1951   146.0  166.0
# 1952   172.0  194.0
# 1953   180.0  201.0

# %%
for month in flights.columns:
    sns.lineplot(data=flights,x="year",y=month,label=month)

plt.legend()
plt.show()

# %%
#regression plot
sns.lmplot(data=tips,x='total_bill',y='tip',hue='sex')
plt.show()
